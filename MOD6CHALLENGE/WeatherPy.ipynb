# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.6.tar.gz (675 kB)
#      ---------------------------------------- 0.0/675.6 kB ? eta -:--:--
#      - ----------------------------------- 30.7/675.6 kB 660.6 kB/s eta 0:00:01
#      ------ ------------------------------- 122.9/675.6 kB 1.4 MB/s eta 0:00:01
#      ------------- ------------------------ 245.8/675.6 kB 1.9 MB/s eta 0:00:01
#      ---------------------- --------------- 399.4/675.6 kB 2.3 MB/s eta 0:00:01
#      ---------------------------- --------- 501.8/675.6 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 675.6/675.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675977 sha256=7f0d13e31b8aa348eb05685215d2a630238a6f9cf6caa5bdfac1b1c7510c11c2
#   Stored in directory: c:\users\truon\appdata\local\pip\cache\wheels\41\82\37\8bb56372b0d828d226b83e0117780ecbe9f409100ac52364bd
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 562

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
#     print(city_url)
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
#         print(city_weather)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | vadso
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | ciudad sandino
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | ancud
# Processing Record 11 of Set 1 | okhotsk
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | colonia
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | lyubymivka
# Processing Record 16 of Set 1 | nizhneangarsk
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | enewetak
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | puerto natales
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | verkhniy baskunchak
# Processing Record 23 of Set 1 | colonel hill
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | ataq
# Processing Record 26 of Set 1 | isangel
# Processing Record 27 of Set 1 | kem'
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | edinburgh of the seven seas
# Processing Record 30 of Set 1 | invercargill
# Processing Record 31 of Set 1 | saint-louis
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | taiyuan
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | along
# Processing Record 36 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 1 | udachny
# Processing Record 38 of Set 1 | broken hill
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | argo
# Processing Record 42 of Set 1 | sheridan
# Processing Record 43 of Set 1 | atafu village
# Processing Record 44 of Set 1 | fort bragg
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | wailua homesteads
# Processing Record 47 of Set 1 | contamana
# Processing Record 48 of Set 1 | riosucio
# Processing Record 49 of Set 1 | cockburn town
# Processing Record 50 of Set 1 | greymouth
# Processing Record 0 of Set 2 | rifle
# Processing Record 1 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | toliara
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | city of balikpapan
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | papatowai
# Processing Record 9 of Set 2 | richards bay
# Processing Record 10 of Set 2 | loreto
# Processing Record 11 of Set 2 | gadzhiyevo
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 14 of Set 2 | dudinka
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | utrik
# Processing Record 17 of Set 2 | tura
# Processing Record 18 of Set 2 | titusville
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | kaedi
# Processing Record 21 of Set 2 | patterson
# Processing Record 22 of Set 2 | stanley
# Processing Record 23 of Set 2 | boac
# Processing Record 24 of Set 2 | berezovo
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | holualoa
# Processing Record 27 of Set 2 | lepsy
# Processing Record 28 of Set 2 | togur
# Processing Record 29 of Set 2 | olonkinbyen
# Processing Record 30 of Set 2 | dalandzadgad
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | ormara
# Processing Record 33 of Set 2 | mbeni
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 2 | qo'qon
# City not found. Skipping...
# Processing Record 38 of Set 2 | divnomorskoye
# Processing Record 39 of Set 2 | kailua-kona
# Processing Record 40 of Set 2 | antanifotsy
# Processing Record 41 of Set 2 | tsiombe
# Processing Record 42 of Set 2 | san angelo
# Processing Record 43 of Set 2 | isafjordur
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | douglas
# Processing Record 46 of Set 2 | minacu
# City not found. Skipping...
# Processing Record 47 of Set 2 | saipan
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | panaba
# Processing Record 0 of Set 3 | bunia
# Processing Record 1 of Set 3 | sorong
# Processing Record 2 of Set 3 | farsan
# Processing Record 3 of Set 3 | progreso
# Processing Record 4 of Set 3 | nemuro
# Processing Record 5 of Set 3 | lihue
# Processing Record 6 of Set 3 | tazacorte
# Processing Record 7 of Set 3 | valle del guamuez
# Processing Record 8 of Set 3 | mata-utu
# Processing Record 9 of Set 3 | san jose village
# City not found. Skipping...
# Processing Record 10 of Set 3 | neryungri
# Processing Record 11 of Set 3 | labrador city
# Processing Record 12 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 3 | lib
# Processing Record 15 of Set 3 | tual
# Processing Record 16 of Set 3 | anadyr
# Processing Record 17 of Set 3 | tralee
# Processing Record 18 of Set 3 | tateyama
# Processing Record 19 of Set 3 | dakhla
# Processing Record 20 of Set 3 | acajutla
# Processing Record 21 of Set 3 | guymon
# Processing Record 22 of Set 3 | dadukou
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | sisimiut
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | pratt
# Processing Record 27 of Set 3 | iskateley
# Processing Record 28 of Set 3 | fort st. john
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | chegdomyn
# Processing Record 31 of Set 3 | rio grande
# Processing Record 32 of Set 3 | remire-montjoly
# Processing Record 33 of Set 3 | grytviken
# Processing Record 34 of Set 3 | happy valley-goose bay
# Processing Record 35 of Set 3 | jumla
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | muli
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | egilsstadir
# Processing Record 40 of Set 3 | selfoss
# Processing Record 41 of Set 3 | hawaiian paradise park
# Processing Record 42 of Set 3 | punta arenas
# Processing Record 43 of Set 3 | port mathurin
# Processing Record 44 of Set 3 | nagqu
# Processing Record 45 of Set 3 | pathein
# Processing Record 46 of Set 3 | quellon
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | pyapon
# Processing Record 49 of Set 3 | lamesa
# Processing Record 0 of Set 4 | phan thiet
# Processing Record 1 of Set 4 | fale old settlement
# Processing Record 2 of Set 4 | zhezqazghan
# Processing Record 3 of Set 4 | bowen
# Processing Record 4 of Set 4 | koubia
# Processing Record 5 of Set 4 | boden
# Processing Record 6 of Set 4 | st. john's
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | del rio
# Processing Record 9 of Set 4 | tsumeb
# Processing Record 10 of Set 4 | bilkha
# Processing Record 11 of Set 4 | chandbali
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | charters towers
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | khouribga
# Processing Record 16 of Set 4 | ghadamis
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | segezha
# Processing Record 19 of Set 4 | qaqortoq
# Processing Record 20 of Set 4 | ahar
# Processing Record 21 of Set 4 | murun-kuren
# Processing Record 22 of Set 4 | qamdo
# Processing Record 23 of Set 4 | whitecourt
# Processing Record 24 of Set 4 | tannum sands
# Processing Record 25 of Set 4 | kristiansund
# Processing Record 26 of Set 4 | muynoq
# Processing Record 27 of Set 4 | west island
# Processing Record 28 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | badger
# Processing Record 31 of Set 4 | brisas de zicatela
# Processing Record 32 of Set 4 | afaahiti
# Processing Record 33 of Set 4 | chui
# Processing Record 34 of Set 4 | chonchi
# Processing Record 35 of Set 4 | florida
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | yuzhno-kurilsk
# Processing Record 38 of Set 4 | mount pearl
# Processing Record 39 of Set 4 | nova sintra
# Processing Record 40 of Set 4 | yeppoon
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | ust-nera
# Processing Record 44 of Set 4 | nar'yan-mar
# Processing Record 45 of Set 4 | marsala
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | maryport
# Processing Record 48 of Set 4 | longjiang
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 0 of Set 5 | perry
# Processing Record 1 of Set 5 | tazovsky
# Processing Record 2 of Set 5 | kohima
# Processing Record 3 of Set 5 | kuta
# Processing Record 4 of Set 5 | ozu
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | tutoia
# Processing Record 8 of Set 5 | bodaybo
# Processing Record 9 of Set 5 | constantia
# Processing Record 10 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 11 of Set 5 | javanrud
# Processing Record 12 of Set 5 | port moresby
# Processing Record 13 of Set 5 | boa vista
# Processing Record 14 of Set 5 | pleasanton
# Processing Record 15 of Set 5 | cotonou
# Processing Record 16 of Set 5 | wabag
# Processing Record 17 of Set 5 | shimoda
# Processing Record 18 of Set 5 | ayaguz
# City not found. Skipping...
# Processing Record 19 of Set 5 | dhuusamarreeb
# Processing Record 20 of Set 5 | namdrik
# Processing Record 21 of Set 5 | sarandi del yi
# Processing Record 22 of Set 5 | boyolangu
# Processing Record 23 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 24 of Set 5 | pasragad branch
# City not found. Skipping...
# Processing Record 25 of Set 5 | teguise
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | puerto baquerizo moreno
# Processing Record 28 of Set 5 | novyy urgal
# Processing Record 29 of Set 5 | tshabong
# Processing Record 30 of Set 5 | woodward
# Processing Record 31 of Set 5 | papao
# Processing Record 32 of Set 5 | kupang
# Processing Record 33 of Set 5 | mingguang
# Processing Record 34 of Set 5 | enshi
# Processing Record 35 of Set 5 | flying fish cove
# Processing Record 36 of Set 5 | northport
# Processing Record 37 of Set 5 | molepolole
# Processing Record 38 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 39 of Set 5 | guiglo
# Processing Record 40 of Set 5 | al mughraqah
# Processing Record 41 of Set 5 | nadi
# Processing Record 42 of Set 5 | jutai
# Processing Record 43 of Set 5 | carutapera
# Processing Record 44 of Set 5 | aydarken
# Processing Record 45 of Set 5 | petaluma
# Processing Record 46 of Set 5 | st. paul
# Processing Record 47 of Set 5 | saryozek
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | wellington
# Processing Record 0 of Set 6 | melfi
# Processing Record 1 of Set 6 | hobyo
# Processing Record 2 of Set 6 | santa ana
# Processing Record 3 of Set 6 | tahoua
# Processing Record 4 of Set 6 | tieli
# Processing Record 5 of Set 6 | mareeba
# Processing Record 6 of Set 6 | mahanoro
# Processing Record 7 of Set 6 | kapuskasing
# Processing Record 8 of Set 6 | kebili
# Processing Record 9 of Set 6 | yanchep
# Processing Record 10 of Set 6 | kingston
# Processing Record 11 of Set 6 | jayapura
# Processing Record 12 of Set 6 | brumado
# Processing Record 13 of Set 6 | kiunga
# Processing Record 14 of Set 6 | beni khalled
# Processing Record 15 of Set 6 | bagli
# Processing Record 16 of Set 6 | kirakira
# Processing Record 17 of Set 6 | roma
# Processing Record 18 of Set 6 | northam
# Processing Record 19 of Set 6 | napier
# Processing Record 20 of Set 6 | klyuchi
# Processing Record 21 of Set 6 | lorengau
# Processing Record 22 of Set 6 | bahia honda
# Processing Record 23 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 6 | waddan
# Processing Record 25 of Set 6 | golfito
# Processing Record 26 of Set 6 | chengyang
# Processing Record 27 of Set 6 | zhangye
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | ixtapa
# Processing Record 30 of Set 6 | ballina
# Processing Record 31 of Set 6 | ar rutbah
# Processing Record 32 of Set 6 | susuman
# Processing Record 33 of Set 6 | undurkhaan
# Processing Record 34 of Set 6 | ghanzi
# Processing Record 35 of Set 6 | keflavik
# Processing Record 36 of Set 6 | opuwo
# Processing Record 37 of Set 6 | karakocan
# Processing Record 38 of Set 6 | chulakkurgan
# Processing Record 39 of Set 6 | aasiaat
# Processing Record 40 of Set 6 | nishinoomote
# Processing Record 41 of Set 6 | shahrak
# Processing Record 42 of Set 6 | ola
# Processing Record 43 of Set 6 | el tambo
# Processing Record 44 of Set 6 | kapa'a
# Processing Record 45 of Set 6 | guarapari
# Processing Record 46 of Set 6 | casablanca
# Processing Record 47 of Set 6 | faya-largeau
# Processing Record 48 of Set 6 | westport
# Processing Record 49 of Set 6 | oistins
# Processing Record 0 of Set 7 | khandyga
# Processing Record 1 of Set 7 | gudari
# Processing Record 2 of Set 7 | oodweyne
# Processing Record 3 of Set 7 | port isabel
# Processing Record 4 of Set 7 | popondetta
# Processing Record 5 of Set 7 | sayat
# Processing Record 6 of Set 7 | hithadhoo
# Processing Record 7 of Set 7 | sosnovo-ozerskoye
# Processing Record 8 of Set 7 | beli
# Processing Record 9 of Set 7 | butte
# Processing Record 10 of Set 7 | piacabucu
# Processing Record 11 of Set 7 | necochea
# Processing Record 12 of Set 7 | amos
# Processing Record 13 of Set 7 | bonthe
# Processing Record 14 of Set 7 | gaiman
# Processing Record 15 of Set 7 | xilin hot
# Processing Record 16 of Set 7 | vorgashor
# Processing Record 17 of Set 7 | ocampo
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | port said
# Processing Record 20 of Set 7 | ouadda
# Processing Record 21 of Set 7 | poronaysk
# Processing Record 22 of Set 7 | fort saskatchewan
# Processing Record 23 of Set 7 | flin flon
# Processing Record 24 of Set 7 | lubartow
# Processing Record 25 of Set 7 | zaraza
# Processing Record 26 of Set 7 | yima
# Processing Record 27 of Set 7 | sadjoavato
# City not found. Skipping...
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | senador jose porfirio
# Processing Record 30 of Set 7 | saint-philippe
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | lahij
# Processing Record 33 of Set 7 | vilyuchinsk
# Processing Record 34 of Set 7 | alofi
# Processing Record 35 of Set 7 | merizo village
# Processing Record 36 of Set 7 | sakiai
# Processing Record 37 of Set 7 | koulikoro
# Processing Record 38 of Set 7 | yanbu
# Processing Record 39 of Set 7 | nkurenkuru
# City not found. Skipping...
# Processing Record 40 of Set 7 | phan rang-thap cham
# Processing Record 41 of Set 7 | at taj
# Processing Record 42 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 7 | rikaze
# Processing Record 44 of Set 7 | arkhangel'sk
# Processing Record 45 of Set 7 | as sulayyil
# Processing Record 46 of Set 7 | linxia chengguanzhen
# Processing Record 47 of Set 7 | lebedyan'
# Processing Record 48 of Set 7 | sao joao dos inhamuns
# Processing Record 49 of Set 7 | castelfranco emilia
# Processing Record 0 of Set 8 | howrah
# Processing Record 1 of Set 8 | la cabecera
# Processing Record 2 of Set 8 | dwarka
# Processing Record 3 of Set 8 | alaghsas
# Processing Record 4 of Set 8 | oarai
# Processing Record 5 of Set 8 | aswan
# Processing Record 6 of Set 8 | marquette
# Processing Record 7 of Set 8 | yung shue wan
# Processing Record 8 of Set 8 | mwene-ditu
# Processing Record 9 of Set 8 | anapa
# Processing Record 10 of Set 8 | korla
# Processing Record 11 of Set 8 | watford city
# Processing Record 12 of Set 8 | kaa-khem
# Processing Record 13 of Set 8 | porbandar
# Processing Record 14 of Set 8 | qarqaraly
# Processing Record 15 of Set 8 | muscat
# Processing Record 16 of Set 8 | arteche
# Processing Record 17 of Set 8 | port sudan
# Processing Record 18 of Set 8 | tumayr
# Processing Record 19 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 8 | lautoka
# Processing Record 21 of Set 8 | luanda
# Processing Record 22 of Set 8 | cocoa west
# Processing Record 23 of Set 8 | pavlovskaya
# Processing Record 24 of Set 8 | severo-yeniseyskiy
# Processing Record 25 of Set 8 | khorol
# Processing Record 26 of Set 8 | mersing
# Processing Record 27 of Set 8 | kone
# Processing Record 28 of Set 8 | santa marta
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | waingapu
# Processing Record 31 of Set 8 | faxinal
# Processing Record 32 of Set 8 | north branch
# Processing Record 33 of Set 8 | coahuayana de hidalgo
# Processing Record 34 of Set 8 | port blair
# Processing Record 35 of Set 8 | brigantine
# Processing Record 36 of Set 8 | hotan
# Processing Record 37 of Set 8 | yarmouth
# Processing Record 38 of Set 8 | yorosso
# Processing Record 39 of Set 8 | elk city
# Processing Record 40 of Set 8 | serdar
# Processing Record 41 of Set 8 | oamaru
# Processing Record 42 of Set 8 | rampura
# Processing Record 43 of Set 8 | road town
# Processing Record 44 of Set 8 | mirny
# Processing Record 45 of Set 8 | howard springs
# Processing Record 46 of Set 8 | brookings
# Processing Record 47 of Set 8 | bangarapet
# Processing Record 48 of Set 8 | balabac
# Processing Record 49 of Set 8 | north bath
# Processing Record 0 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 9 | troitskiy
# Processing Record 2 of Set 9 | mcpherson
# Processing Record 3 of Set 9 | poyang
# Processing Record 4 of Set 9 | cienfuegos
# Processing Record 5 of Set 9 | ad dabbah
# Processing Record 6 of Set 9 | bereket
# Processing Record 7 of Set 9 | zhangjiajie
# Processing Record 8 of Set 9 | petrovsk-zabaykal'skiy
# Processing Record 9 of Set 9 | laojunmiao
# Processing Record 10 of Set 9 | olinda
# Processing Record 11 of Set 9 | bridlington
# Processing Record 12 of Set 9 | tsagan aman
# Processing Record 13 of Set 9 | puerto aysen
# Processing Record 14 of Set 9 | dhidhdhoo
# Processing Record 15 of Set 9 | yabelo
# Processing Record 16 of Set 9 | tiznit
# Processing Record 17 of Set 9 | todos santos
# Processing Record 18 of Set 9 | polyarnyy
# Processing Record 19 of Set 9 | cherdyn'
# Processing Record 20 of Set 9 | kolwezi
# Processing Record 21 of Set 9 | guelmim
# Processing Record 22 of Set 9 | cox's bazar
# Processing Record 23 of Set 9 | kirensk
# Processing Record 24 of Set 9 | bulawayo
# Processing Record 25 of Set 9 | vila franca do campo
# Processing Record 26 of Set 9 | manggar
# Processing Record 27 of Set 9 | nelson bay
# Processing Record 28 of Set 9 | inhambane
# Processing Record 29 of Set 9 | salekhard
# Processing Record 30 of Set 9 | mizdah
# Processing Record 31 of Set 9 | francistown
# Processing Record 32 of Set 9 | quimili
# Processing Record 33 of Set 9 | port hueneme
# Processing Record 34 of Set 9 | ilion
# Processing Record 35 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 36 of Set 9 | sambava
# Processing Record 37 of Set 9 | callao
# Processing Record 38 of Set 9 | severnoye
# Processing Record 39 of Set 9 | rongelap
# Processing Record 40 of Set 9 | daru
# Processing Record 41 of Set 9 | ishim
# Processing Record 42 of Set 9 | albertina
# Processing Record 43 of Set 9 | dieppe
# Processing Record 44 of Set 9 | hola
# Processing Record 45 of Set 9 | fortuna
# Processing Record 46 of Set 9 | ebaye
# Processing Record 47 of Set 9 | macau
# Processing Record 48 of Set 9 | la sarre
# Processing Record 49 of Set 9 | pyeongchang
# City not found. Skipping...
# Processing Record 0 of Set 10 | celestun
# Processing Record 1 of Set 10 | mukalla
# Processing Record 2 of Set 10 | bandarbeyla
# Processing Record 3 of Set 10 | lake los angeles
# Processing Record 4 of Set 10 | samfya
# Processing Record 5 of Set 10 | levuka
# Processing Record 6 of Set 10 | taoudenni
# Processing Record 7 of Set 10 | pemangkat
# Processing Record 8 of Set 10 | lazaro cardenas
# Processing Record 9 of Set 10 | la'ie
# Processing Record 10 of Set 10 | torpoint
# Processing Record 11 of Set 10 | taroa
# Processing Record 12 of Set 10 | wainwright
# Processing Record 13 of Set 10 | nabire
# Processing Record 14 of Set 10 | puerto francisco de orellana
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | aweil
# Processing Record 17 of Set 10 | armavir
# Processing Record 18 of Set 10 | adrar
# Processing Record 19 of Set 10 | erenhot
# Processing Record 20 of Set 10 | umm kaddadah
# Processing Record 21 of Set 10 | newman
# Processing Record 22 of Set 10 | thunder bay
# Processing Record 23 of Set 10 | tarfaya
# Processing Record 24 of Set 10 | sinabang
# Processing Record 25 of Set 10 | palmer
# Processing Record 26 of Set 10 | uturoa
# Processing Record 27 of Set 10 | pimentel
# Processing Record 28 of Set 10 | rokytne
# Processing Record 29 of Set 10 | dryden
# Processing Record 30 of Set 10 | freetown
# Processing Record 31 of Set 10 | usinsk
# Processing Record 32 of Set 10 | calabozo
# Processing Record 33 of Set 10 | caetite
# Processing Record 34 of Set 10 | wesselsbron
# Processing Record 35 of Set 10 | nizhnesortymskiy
# Processing Record 36 of Set 10 | jiujiang
# Processing Record 37 of Set 10 | bazarnyy karabulak
# Processing Record 38 of Set 10 | biryusinsk
# Processing Record 39 of Set 10 | kushiro
# Processing Record 40 of Set 10 | manokwari
# Processing Record 41 of Set 10 | yatsuomachi-higashikumisaka
# Processing Record 42 of Set 10 | lido di ostia
# Processing Record 43 of Set 10 | konosha
# Processing Record 44 of Set 10 | comodoro rivadavia
# Processing Record 45 of Set 10 | japekrom
# City not found. Skipping...
# Processing Record 46 of Set 10 | ajdabiya
# Processing Record 47 of Set 10 | mournies
# Processing Record 48 of Set 10 | kikwit
# Processing Record 49 of Set 10 | juneau
# Processing Record 0 of Set 11 | terrigal
# Processing Record 1 of Set 11 | xai-xai
# Processing Record 2 of Set 11 | mongu
# Processing Record 3 of Set 11 | porto cristo
# Processing Record 4 of Set 11 | nurota
# Processing Record 5 of Set 11 | cabedelo
# Processing Record 6 of Set 11 | whakatane
# Processing Record 7 of Set 11 | wonosobo
# Processing Record 8 of Set 11 | hami
# Processing Record 9 of Set 11 | acarau
# Processing Record 10 of Set 11 | shamva
# Processing Record 11 of Set 11 | pushkinskiye gory
# Processing Record 12 of Set 11 | sarmiento
# Processing Record 13 of Set 11 | buala
# Processing Record 14 of Set 11 | gulf shores
# Processing Record 15 of Set 11 | cooper's town
# Processing Record 16 of Set 11 | moree
# Processing Record 17 of Set 11 | greenland
# Processing Record 18 of Set 11 | saint-pierre
# Processing Record 19 of Set 11 | tucuma
# Processing Record 20 of Set 11 | laguna
# Processing Record 21 of Set 11 | sao raimundo nonato
# Processing Record 22 of Set 11 | barah
# Processing Record 23 of Set 11 | ilsede
# Processing Record 24 of Set 11 | norman gardens
# Processing Record 25 of Set 11 | la foa
# Processing Record 26 of Set 11 | island harbour
# Processing Record 27 of Set 11 | niafunke
# Processing Record 28 of Set 11 | latur
# Processing Record 29 of Set 11 | kolyvan'
# Processing Record 30 of Set 11 | kodinsk
# Processing Record 31 of Set 11 | alpatovo
# Processing Record 32 of Set 11 | port-gentil
# Processing Record 33 of Set 11 | auxerre
# Processing Record 34 of Set 11 | trevelin
# Processing Record 35 of Set 11 | guankou
# Processing Record 36 of Set 11 | lae
# Processing Record 37 of Set 11 | argostolion
# Processing Record 38 of Set 11 | inyonga
# Processing Record 39 of Set 11 | otofuke
# Processing Record 40 of Set 11 | arrifes
# Processing Record 41 of Set 11 | sarpang
# Processing Record 42 of Set 11 | palikir - national government center
# Processing Record 43 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 44 of Set 11 | fraserburgh
# Processing Record 45 of Set 11 | huarmey
# Processing Record 46 of Set 11 | fauske
# Processing Record 47 of Set 11 | alaca
# Processing Record 48 of Set 11 | sechura
# Processing Record 49 of Set 11 | marsh harbour
# Processing Record 0 of Set 12 | namibe
# Processing Record 1 of Set 12 | mosrentgen
# Processing Record 2 of Set 12 | tuba city
# Processing Record 3 of Set 12 | paradip garh
# Processing Record 4 of Set 12 | tvoroyri
# Processing Record 5 of Set 12 | padang
# Processing Record 6 of Set 12 | gizo
# Processing Record 7 of Set 12 | pauini
# Processing Record 8 of Set 12 | houlton
# Processing Record 9 of Set 12 | cabo san lucas
# Processing Record 10 of Set 12 | mikun'
# Processing Record 11 of Set 12 | gwanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'port alfred', 'Lat': -33.5906, 'Lng': 26.891, 'Max Temp': 14.34, 'Humidity': 81, 'Cloudiness': 0, 'Wind Speed': 3.3, 'Country': 'ZA', 'Date': 1693168460}, {'City': 'vadso', 'Lat': 70.0744, 'Lng': 29.7487, 'Max Temp': 8.49, 'Humidity': 93, 'Cloudiness': 20, 'Wind Speed': 2.57, 'Country': 'NO', 'Date': 1693168460}, {'City': 'adamstown', 'Lat': -25.066, 'Lng': -130.1015, 'Max Temp': 19.91, 'Humidity': 80, 'Cloudiness': 76, 'Wind Speed': 7.49, 'Country': 'PN', 'Date': 1693168460}, {'City': 'blackmans bay', 'Lat': -43.0167, 'Lng': 147.3167, 'Max Temp': 2.51, 'Humidity': 93, 'Cloudiness': 0, 'Wind Speed': 2.8, 'Country': 'AU', 'Date': 1693168460}, {'City': 'port-aux-francais', 'Lat': -49.35, 'Lng': 70.2167, 'Max Temp': 6.4, 'Humidity': 96, 'Cloudiness': 100, 'Wind Speed': 17.71, 'Country': 'TF', 'Date': 1693168460}, {'City': 'bredasdorp', 'Lat': -34.5322, 'Lng': 20.0403, 'Max Temp': 9.05, 'Humidity': 86, 'Cloudiness': 0, 'Wind Speed': 2.05, 'Country': 'ZA', 'Date': 1693168461}, {'City': 'ciudad sandino', 'Lat': 12.1589, 'Lng': -86.3442, 'Max Temp': 30.7, 'Humidity': 70, 'Cloudiness': 40, 'Wind Speed': 3.09, 'Country': 'NI', 'Date': 1693168461}, {'City': 'waitangi', 'Lat': -43.9535, 'Lng': -176.5597, 'Max Temp': 7.68, 'Humidity': 96, 'Cloudiness': 100, 'Wind Speed': 0.45, 'Country': 'NZ', 'Date': 1693168461}, {'City': 'klaksvik', 'Lat': 62.2266, 'Lng': -6.589, 'Max Temp': 11.51, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 2.6, 'Country': 'FO', 'Date': 1693168461}, {'City': 'ancud', 'Lat': -41.8697, 'Lng': -73.8203, 'Max Temp': 9.96, 'Humidity': 83, 'Cloudiness': 100, 'Wind Speed': 8.74, 'Country': 'CL', 'Date': 1693168461}, {'City': 'okhotsk', 'Lat': 59.3833, 'Lng': 143.3, 'Max Temp': 15.55, 'Humidity': 64, 'Cloudiness': 30, 'Wind Speed': 3.18, 'Country': 'RU', 'Date': 1693168461}, {'City': 'college', 'Lat': 64.8569, 'Lng': -147.8028, 'Max Temp': 18.99, 'Humidity': 68, 'Cloudiness': 75, 'Wind Speed': 1.54, 'Country': 'US', 'Date': 1693168462}, {'City': 'colonia', 'Lat': 50.9333, 'Lng': 6.95, 'Max Temp': 16.03, 'Humidity': 81, 'Cloudiness': 0, 'Wind Speed': 1.54, 'Country': 'DE', 'Date': 1693168308}, {'City': 'albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max Temp': 25.69, 'Humidity': 61, 'Cloudiness': 75, 'Wind Speed': 1.49, 'Country': 'US', 'Date': 1693168302}, {'City': 'lyubymivka', 'Lat': 46.8106, 'Lng': 33.5686, 'Max Temp': 23.68, 'Humidity': 56, 'Cloudiness': 5, 'Wind Speed': 3.35, 'Country': 'UA', 'Date': 1693168462}, {'City': 'nizhneangarsk', 'Lat': 55.7833, 'Lng': 109.55, 'Max Temp': 12.54, 'Humidity': 73, 'Cloudiness': 92, 'Wind Speed': 0.87, 'Country': 'RU', 'Date': 1693168462}, {'City': 'ilulissat', 'Lat': 69.2167, 'Lng': -51.1, 'Max Temp': 10.01, 'Humidity': 53, 'Cloudiness': 75, 'Wind Speed': 6.17, 'Country': 'GL', 'Date': 1693168189}, {'City': 'enewetak', 'Lat': 11.3474, 'Lng': 162.3373, 'Max Temp': 28.25, 'Humidity': 79, 'Cloudiness': 100, 'Wind Speed': 11.8, 'Country': 'MH', 'Date': 1693168463}, {'City': 'hermanus', 'Lat': -34.4187, 'Lng': 19.2345, 'Max Temp': 12.33, 'Humidity': 75, 'Cloudiness': 0, 'Wind Speed': 3.66, 'Country': 'ZA', 'Date': 1693168463}, {'City': 'puerto natales', 'Lat': -51.7236, 'Lng': -72.4875, 'Max Temp': 3.47, 'Humidity': 98, 'Cloudiness': 100, 'Wind Speed': 0.74, 'Country': 'CL', 'Date': 1693168463}, {'City': 'carnarvon', 'Lat': -24.8667, 'Lng': 113.6333, 'Max Temp': 17.91, 'Humidity': 73, 'Cloudiness': 0, 'Wind Speed': 3.66, 'Country': 'AU', 'Date': 1693168463}, {'City': 'verkhniy baskunchak', 'Lat': 48.2256, 'Lng': 46.7217, 'Max Temp': 20.54, 'Humidity': 42, 'Cloudiness': 27, 'Wind Speed': 4.95, 'Country': 'RU', 'Date': 1693168463}, {'City': 'colonel hill', 'Lat': 22.7667, 'Lng': -74.2167, 'Max Temp': 28.82, 'Humidity': 69, 'Cloudiness': 100, 'Wind Speed': 1.94, 'Country': 'BS', 'Date': 1693168464}, {'City': 'margaret river', 'Lat': -33.95, 'Lng': 115.0667, 'Max Temp': 14.78, 'Humidity': 87, 'Cloudiness': 84, 'Wind Speed': 5.59, 'Country': 'AU', 'Date': 1693168422}, {'City': 'at ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          537
# Lat           537
# Lng           537
# Max Temp      537
# Humidity      537
# Cloudiness    537
# Wind Speed    537
# Country       537
# Date          537
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        port alfred -33.5906   26.8910     14.34        81           0
# 1              vadso  70.0744   29.7487      8.49        93          20
# 2          adamstown -25.0660 -130.1015     19.91        80          76
# 3      blackmans bay -43.0167  147.3167      2.51        93           0
# 4  port-aux-francais -49.3500   70.2167      6.40        96         100
#
#    Wind Speed Country        Date
# 0        3.30      ZA  1693168460
# 1        2.57      NO  1693168460
# 2        7.49      PN  1693168460
# 3        2.80      AU  1693168460
# 4       17.71      TF  1693168460

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              port alfred -33.5906   26.8910     14.34        81           0
# 1                    vadso  70.0744   29.7487      8.49        93          20
# 2                adamstown -25.0660 -130.1015     19.91        80          76
# 3            blackmans bay -43.0167  147.3167      2.51        93           0
# 4        port-aux-francais -49.3500   70.2167      6.40        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.30      ZA  1693168460
# 1              2.57      NO  1693168460
# 2              7.49      PN  1693168460
# 3              2.80      AU  1693168460
# 4             17.71      TF  1693168460

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.grid(True)
plt.title("Latitude Vs. Temperature Scatter")
plt.xlabel("Latitude")
plt.ylabel("Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.grid(True)
plt.title("Latitude Vs. Humidity Scatter")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.grid(True)
plt.title("Latitude Vs. Cloudiness Scatter")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.grid(True)
plt.title("Latitude Vs. Wind Speed Scatter")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_linear_regression_plot(df, x_col, y_col):
    x = df[x_col]
    y = df[y_col]

    # Perform linear regression using scipy.stats.linregress
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    
    # Create the regression line
    regression_line = slope * x + intercept

    # Create a scatter plot of the original data points
    plt.scatter(x, y, color='blue', label='Actual Data')

    # Plot the regression line
    plt.plot(x, regression_line, color='red', label='Regression Line')

    # Add labels and legend
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title('Linear Regression Plot')
    plt.legend()

    # Show the plot
    plt.show()

# # Example usage
# create_linear_regression_plot(city_data_df, 'Population', 'GDP')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]



# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 vadso  70.0744   29.7487      8.49        93          20
# 6        ciudad sandino  12.1589  -86.3442     30.70        70          40
# 8              klaksvik  62.2266   -6.5890     11.51        88         100
# 10              okhotsk  59.3833  143.3000     15.55        64          30
# 11              college  64.8569 -147.8028     18.99        68          75
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      NO  1693168460
# 6              3.09      NI  1693168461
# 8              2.60      FO  1693168461
# 10             3.18      RU  1693168461
# 11             1.54      US  1693168462

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              port alfred -33.5906   26.8910     14.34        81           0
# 2                adamstown -25.0660 -130.1015     19.91        80          76
# 3            blackmans bay -43.0167  147.3167      2.51        93           0
# 4        port-aux-francais -49.3500   70.2167      6.40        96         100
# 5               bredasdorp -34.5322   20.0403      9.05        86           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.30      ZA  1693168460
# 2              7.49      PN  1693168460
# 3              2.80      AU  1693168460
# 4             17.71      TF  1693168460
# 5              2.05      ZA  1693168461

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere data
create_linear_regression_plot(northern_hemi_df, 'Lat', 'Max Temp')

# %%
# Linear regression on Southern Hemisphere
# Perform linear regression on Northern Hemisphere data
create_linear_regression_plot(southern_hemi_df, 'Lat', 'Max Temp')

# %% [markdown]
# Closer to the equator (0 Lat) = Higher Temperature

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df, 'Lat', 'Humidity')

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df, 'Lat', 'Humidity')

# %% [markdown]
# Subtly less humidity when closer to equator

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df, 'Lat', 'Cloudiness')

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df, 'Lat', 'Cloudiness')

# %% [markdown]
# Cloudiness appears to also subtly decrease when closer to equator line.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(northern_hemi_df, 'Lat', 'Wind Speed')

# %%
# Southern Hemisphere
create_linear_regression_plot(southern_hemi_df, 'Lat', 'Wind Speed')

# %% [markdown]
# Weak linear relationships when comparing latitude and windspeed
